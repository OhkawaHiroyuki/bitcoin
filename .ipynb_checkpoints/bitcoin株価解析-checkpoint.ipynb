# %%
import pandas as pd
import gzip
#import pandas_profiling as pdp
from IPython.display import display
import dask.dataframe as dd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import matplotlib as mpl
import matplotlib.patches as mpatches

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

import os
import statsmodels.tsa.api as smt
import statsmodels.api as sm
from statsmodels.tsa.arima_model import AR, ARMA

sns.set_style('whitegrid')
# %matplotlib inline



# %matplotlib inline
sns.set()
plt.rcParams['font.family'] = 'HGMaruGothicMPRO'
print(mpl.rcParams['font.family'])
# Out:
# ['HGMaruGothicMPRO']

# %%
# グラフを横長にする
from matplotlib import rcParams
rcParams['figure.figsize'] = 10, 6
sns.set()
# オブジェクトの保存
import pickle
# pystanの読み込み
import pystan

# %% [markdown]
# # データ読み込みからデータ成型まで

# %%
col_names = [ '日付開始','価格','最高価格','最低価格','終値','ボリューム','時価総額']
df_bitcoin = pd.read_csv('bitcoin2.csv',encoding="utf-8", names=col_names,skipinitialspace=True)
df_bitcoin.isnull().sum()
df_bitcoin=df_bitcoin.drop(0)

# %% [markdown]
# ### 日付の表示形式を変更

# %%
df_bitcoin['日付開始'] = df_bitcoin['日付開始'].str.replace('年', '-')
df_bitcoin['日付開始'] = df_bitcoin['日付開始'].str.replace('月', '-')
df_bitcoin['日付開始'] = df_bitcoin['日付開始'].str.replace('日', '')
df_bitcoin['価格'] = df_bitcoin['価格'].str.replace(',', '')
df_bitcoin['最高価格'] = df_bitcoin['最高価格'].str.replace(',', '')
df_bitcoin['最低価格'] = df_bitcoin['最低価格'].str.replace(',', '')
df_bitcoin['終値'] = df_bitcoin['終値'].str.replace(',', '')
df_bitcoin['ボリューム'] = df_bitcoin['ボリューム'].str.replace(',', '')
df_bitcoin['時価総額'] = df_bitcoin['時価総額'].str.replace(',', '')

# %%
df_bitcoin['日付開始']=pd.to_datetime(df_bitcoin['日付開始'],format='%Y-%m-%d')

# %%
df_bitcoin.dtypes
df_bitcoin['価格']=df_bitcoin['価格'].astype('double')
df_bitcoin['最高価格']=df_bitcoin['最高価格'].astype('double')
df_bitcoin['最低価格']=df_bitcoin['最低価格'].astype('double')
df_bitcoin['終値']=df_bitcoin['終値'].astype('double')
#df_bitcoin['ボリューム']=df_bitcoin['ボリューム'].astype('double')
df_bitcoin['時価総額']=df_bitcoin['時価総額'].astype('double')

# %%
df_bitcoin=df_bitcoin.sort_values(by='日付開始',ascending=False)

# %%
df_bitcoin=df_bitcoin.drop(labels='ボリューム',axis=1)

# %%
df_bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1943 entries, 1 to 1943
# Data columns (total 22 columns):
# 日付開始                1943 non-null datetime64[ns]
# 価格                  1943 non-null float64
# 最高価格                1943 non-null float64
# 最低価格                1943 non-null float64
# 終値                  1943 non-null float64
# 時価総額                1943 non-null float64
# kouteisa            1943 non-null float64
# difference_1day     1942 non-null float64
# difference_3day     1940 non-null float64
# difference_7day     1936 non-null float64
# difference_30day    1913 non-null float64
# difference_60day    1883 non-null float64
# pct_1d              1942 non-null float64
# pct_3d              1940 non-null float64
# pct_7d              1936 non-null float64
# pct_30d             1913 non-null float64
# pct_60d             1883 non-null float64
# rolling_mean_1d     1943 non-null float64
# rolling_mean_3d     1941 non-null float64
# rolling_mean_7d     1937 non-null float64
# rolling_mean_30d    1914 non-null float64
# rolling_mean_60d    1884 non-null float64
# dtypes: datetime64[ns](1), float64(21)
# memory usage: 349.1 KB

# %% [markdown]
# # 基礎集計

# %% [markdown]
# ## 時系列ごとに見てみる

# %%
bitgroup=df_bitcoin.groupby(pd.Grouper(key='日付開始',freq='1d')).sum()

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['価格'])

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['最高価格'])

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['時価総額'])

# %%
bitcoin_1m_mean=df_bitcoin.groupby(pd.Grouper(key='日付開始',freq='1m')).mean()
bitcoin_1m_mean=bitcoin_1m_mean.reset_index()

# %%
bitcoin_1y_mean=df_bitcoin.groupby(pd.Grouper(key='日付開始',freq='1y')).mean()
bitcoin_1y_mean=bitcoin_1y_mean.reset_index()
bitcoin_1y_mean
# Out:
#         日付開始           価格         最高価格         最低価格           終値          時価総額
# 0 2013-12-31   255.147944   269.322379   239.651935   257.474395  3.031221e+09
# 1 2014-12-31   528.404740   540.312000   514.366740   527.236548  6.795851e+09
# 2 2015-12-31   272.149041   278.151863   266.807918   272.453397  3.916406e+09
# 3 2016-12-31   567.141503   574.302295   560.453415   568.492213  8.906763e+09
# 4 2017-12-31  3970.644849  4144.687534  3811.707808  4006.033616  6.586193e+10
# 5 2018-12-31  8689.293632  8933.006923  8358.743419  8655.518632  1.474954e+11

# %%
plt.figure(figsize=(20, 20))
plt.plot(bitcoin_1m_mean['日付開始'],bitcoin_1m_mean['価格'])

# %%
plt.figure(figsize=(20, 20))
plt.plot(bitcoin_1y_mean['日付開始'],bitcoin_1y_mean['価格'])

# %% [markdown]
# # 新カラム作成

# %%
df_bitcoin['kouteisa']=df_bitcoin['最高価格']-df_bitcoin['最低価格']

# %%
df_bitcoin['difference_1day'] = df_bitcoin['価格'].diff(periods=1)
df_bitcoin['difference_3day'] = df_bitcoin['価格'].diff(periods=3)
df_bitcoin['difference_7day'] = df_bitcoin['価格'].diff(periods=7)
df_bitcoin['difference_30day'] = df_bitcoin['価格'].diff(periods=30)
df_bitcoin['difference_60day'] = df_bitcoin['価格'].diff(periods=60)

# %%
df_bitcoin['pct_1d'] = df_bitcoin['価格'].pct_change(periods=1)
df_bitcoin['pct_3d'] = df_bitcoin['価格'].pct_change(periods=3)
df_bitcoin['pct_7d'] = df_bitcoin['価格'].pct_change(periods=7)
df_bitcoin['pct_30d'] = df_bitcoin['価格'].pct_change(periods=30)
df_bitcoin['pct_60d'] = df_bitcoin['価格'].pct_change(periods=60)

# %%
df_bitcoin['rolling_mean_1d']=pd.rolling_mean(df_bitcoin['価格'],window=1)
df_bitcoin['rolling_mean_3d']=pd.rolling_mean(df_bitcoin['価格'],window=3)
df_bitcoin['rolling_mean_7d']=pd.rolling_mean(df_bitcoin['価格'],window=7)
df_bitcoin['rolling_mean_30d']=pd.rolling_mean(df_bitcoin['価格'],window=30)
df_bitcoin['rolling_mean_60d']=pd.rolling_mean(df_bitcoin['価格'],window=60)
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=1,center=False).mean()
#   """Entry point for launching an IPython kernel.
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=3,center=False).mean()
#
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=7,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=30,center=False).mean()
#   after removing the cwd from sys.path.
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=60,center=False).mean()
#   """

# %% [markdown]
# # 新カラムを基礎集計

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['kouteisa'])

# %% [markdown]
# ## 差分集計

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['difference_1day'])

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['difference_7day'])

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['difference_30day'])

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['difference_60day'])

# %% [markdown]
# ## 移動平均

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['rolling_mean_1d'])

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['rolling_mean_30d'])

# %% [markdown]
# # 変化率

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['pct_1d'])

# %%
plt.figure(figsize=(20, 20))
plt.plot(df_bitcoin['日付開始'],df_bitcoin['pct_30d'])

# %% [markdown]
# ### 自己相関

# %%
plt.figure(figsize=(7, 20))

diff = df_bitcoin['pct_1d'].dropna()
sm.graphics.tsa.plot_acf(diff, lags=60)
plt.show()

# %%
plt.figure(figsize=(7, 20))

diff = df_bitcoin['pct_30d'].dropna()
sm.graphics.tsa.plot_acf(diff, lags=60)
plt.show()

# %% [markdown]
# ### 偏自己相関

# %%
plt.figure(figsize=(7, 20))

diff = df_bitcoin['pct_1d'].dropna()
sm.graphics.tsa.plot_pacf(diff, lags=60)
plt.show()

# %%
plt.figure(figsize=(7, 20))

diff = df_bitcoin['pct_30d'].dropna()
sm.graphics.tsa.plot_pacf(diff, lags=70)
plt.show()

# %% [markdown]
# # ARIMA方式

# %% [markdown]
# ## 一日後のやつ

# %%
# ADF検定（原型列で確認だけ）
res_ctt = sm.tsa.stattools.adfuller(diff, regression="ctt") # トレンド項あり（２次）、定数項あり
res_ct = sm.tsa.stattools.adfuller(diff, regression="ct") # トレンド項あり（１次）、定数項あり
res_c = sm.tsa.stattools.adfuller(diff, regression="c") # トレンド項なし、定数項あり
res_nc = sm.tsa.stattools.adfuller(diff, regression="nc") # トレンド項なし、定数項なし
print(res_ctt)
print(res_ct)
print(res_c)
print(res_nc)
# Out:
# (-8.30782202808177, 5.925235063635968e-11, 22, 1919, {'1%': -4.377178439896441, '5%': -3.8354708966744484, '10%': -3.5551684812229576}, -6462.919678875773)
# (-8.309811933693283, 1.3751471338441887e-11, 22, 1919, {'1%': -3.963495351951755, '5%': -3.4127803184073815, '10%': -3.128398437422306}, -6464.913422772221)
# (-8.288091360475807, 4.335559145180794e-13, 22, 1919, {'1%': -3.4337622297208146, '5%': -2.863047304445204, '10%': -2.567572430319552}, -6466.398379294082)
# (-8.241180323552623, 9.229987039098704e-14, 22, 1919, {'1%': -2.5669060708946843, '5%': -1.9411408780817336, '10%': -1.6166823279784637}, -6467.625477913338)

# %%
diff=diff.values.tolist()

# %%
res_selection = sm.tsa.arma_order_select_ic(diff, ic='aic', trend='nc')
res_selection
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# {'aic':              0            1            2
#  0          NaN -6555.794779 -6553.974130
#  1 -6555.792417 -6553.821467 -6552.068956
#  2 -6553.995272 -6552.105332 -6578.487789
#  3 -6552.860756 -6551.259848 -6576.567482
#  4 -6552.010107 -6558.935702 -6557.267726, 'aic_min_order': (2, 2)}

# %%
sarimax = sm.tsa.SARIMAX(diff, 
                        order=(2, 1, 2),
                        seasonal_order=(1, 1, 1, 17),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()

# %%
sarimax_resid = sarimax.resid # モデルの残差成分

# %%
# モデル残差のコレログラム
fig = plt.figure(figsize=(8, 8))

# 自己相関(ACF)のグラフ
ax1 = fig.add_subplot(211)
sm.graphics.tsa.plot_acf(sarimax_resid, lags=50, ax=ax1) #ACF計算とグラフ自動作成

# 偏自己相関(PACF)のグラフ
ax2 = fig.add_subplot(212)
sm.graphics.tsa.plot_pacf(sarimax_resid, lags=50, ax=ax2) #PACF計算とグラフ自動作成

plt.tight_layout() # グラフ間スキマ調整

# %%
# SRIMAモデル（試しに）季節調整なし
sarimax_noseasonal = sm.tsa.SARIMAX(diff, 
                        order=(2, 1, 2),
                        seasonal_order=(0, 0, 0, 0),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()

sarimax_noseasonal_resid = sarimax_noseasonal.resid # 残差成分

fig = plt.figure(figsize=(8, 8))

# 自己相関(ACF)のグラフ
ax1 = fig.add_subplot(211)
sm.graphics.tsa.plot_acf(sarimax_noseasonal_resid, lags=50, ax=ax1) #ACF計算とグラフ自動作成

# 偏自己相関(PACF)のグラフ
ax2 = fig.add_subplot(212)
sm.graphics.tsa.plot_pacf(sarimax_noseasonal_resid, lags=50, ax=ax2) #PACF計算とグラフ自動作成

plt.tight_layout() # グラフ間スキマ調整

# %%
print(sarimax.aic) 
print(sarimax_noseasonal.aic)
# Out:
# -6330.481601563466
# -6527.931977090535

# %%
# SARIMAパラメター最適化（総当たりチェック）


# パラメータ範囲
# order(p, d, q)
min_p = 1; max_p = 3 # min_pは1以上を指定しないとエラー
min_d = 0; max_d = 1
min_q = 0; max_q = 3 

# seasonal_order(sp, sd, sq)
min_sp = 0; max_sp = 1
min_sd = 0; max_sd = 1
min_sq = 0; max_sq = 1

test_pattern = (max_p - min_p +1)*(max_q - min_q + 1)*(max_d - min_d + 1)*(max_sp - min_sp + 1)*(max_sq - min_sq + 1)*(max_sd - min_sd + 1)
print("pattern:", test_pattern)

sfq = 12 # seasonal_order周期パラメータ
ts = diff # 時系列データ

test_results = pd.DataFrame(index=range(test_pattern), columns=["model_parameters", "aic"])
num = 0
for p in range(min_p, max_p + 1):
    for d in range(min_d, max_d + 1):
        for q in range(min_q, max_q + 1):
            for sp in range(min_sp, max_sp + 1):
                for sd in range(min_sd, max_sd + 1):
                    for sq in range(min_sq, max_sq + 1):
                        sarima = sm.tsa.SARIMAX(
                            ts, order=(p, d, q), 
                            seasonal_order=(sp, sd, sq, sfq), 
                            enforce_stationarity = False, 
                            enforce_invertibility = False
                        ).fit()
                        test_results.iloc[num]["model_parameters"] = "order=(" + str(p) + ","+ str(d) + ","+ str(q) + "), seasonal_order=("+ str(sp) + ","+ str(sd) + "," + str(sq) + ")"
                        test_results.iloc[num]["aic"] = sarima.aic
                        print(num,'/', test_pattern-1, test_results.iloc[num]["model_parameters"],  test_results.iloc[num]["aic"] )
                        num = num + 1

# 結果（最小AiC）
print("best[aic] parameter ********")
print(test_results[test_results.aic == min(test_results.aic)])
# Out:
# pattern: 192
# 0 / 191 order=(1,0,0), seasonal_order=(0,0,0) -6551.8226867995445
# 1 / 191 order=(1,0,0), seasonal_order=(0,0,1) -6502.0387740987735
# 2 / 191 order=(1,0,0), seasonal_order=(0,1,0) -5184.108167984807
# 3 / 191 order=(1,0,0), seasonal_order=(0,1,1) -6406.874596139774
# 4 / 191 order=(1,0,0), seasonal_order=(1,0,0) -6502.030864304221
# 5 / 191 order=(1,0,0), seasonal_order=(1,0,1) -6499.809533252172
# 6 / 191 order=(1,0,0), seasonal_order=(1,1,0) -5653.22242152803
# 7 / 191 order=(1,0,0), seasonal_order=(1,1,1) -6396.586828347088
# 8 / 191 order=(1,0,1), seasonal_order=(0,0,0) -6547.608716940056
# 9 / 191 order=(1,0,1), seasonal_order=(0,0,1) -6499.818315410359
# 10 / 191 order=(1,0,1), seasonal_order=(0,1,0) -5243.310160994734
# 11 / 191 order=(1,0,1), seasonal_order=(0,1,1) -6404.934129958194
# 12 / 191 order=(1,0,1), seasonal_order=(1,0,0) -6501.939356927482
# 13 / 191 order=(1,0,1), seasonal_order=(1,0,1) -6497.9846729329665
# 14 / 191 order=(1,0,1), seasonal_order=(1,1,0) -5683.317692061309
# 15 / 191 order=(1,0,1), seasonal_order=(1,1,1) -6395.030943659753
# 16 / 191 order=(1,0,2), seasonal_order=(0,0,0) -6541.728506747508
# 17 / 191 order=(1,0,2), seasonal_order=(0,0,1) -6494.588083637963
# 18 / 191 order=(1,0,2), seasonal_order=(0,1,0) -5177.166495431578
# 19 / 191 order=(1,0,2), seasonal_order=(0,1,1) -6396.512334918401
# 20 / 191 order=(1,0,2), seasonal_order=(1,0,0) -6500.167964659571
# 21 / 191 order=(1,0,2), seasonal_order=(1,0,1) -6492.9238992385
# 22 / 191 order=(1,0,2), seasonal_order=(1,1,0) -5652.856646374543
# 23 / 191 order=(1,0,2), seasonal_order=(1,1,1) -6387.926826289033
# 24 / 191 order=(1,0,3), seasonal_order=(0,0,0) -6533.388135584948
# 25 / 191 order=(1,0,3), seasonal_order=(0,0,1) -6486.181018537719
# 26 / 191 order=(1,0,3), seasonal_order=(0,1,0) -5173.81848198942
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-523-9b0dd5b80cca> in <module>()
#      31                             seasonal_order=(sp, sd, sq, sfq),
#      32                             enforce_stationarity = False,
# ---> 33                             enforce_invertibility = False
#      34                         ).fit()
#      35                         test_results.iloc[num]["model_parameters"] = "order=(" + str(p) + ","+ str(d) + ","+ str(q) + "), seasonal_order=("+ str(sp) + ","+ str(sd) + "," + str(sq) + ")"
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, **kwargs)
#     452         else:
#     453             res = self.smooth(mlefit.params, transformed=False,
# --> 454                               cov_type=cov_type, cov_kwds=cov_kwds)
#     455
#     456             res.mlefit = mlefit
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in smooth(self, params, **kwargs)
#     866         kwargs.setdefault('results_class', SARIMAXResults)
#     867         kwargs.setdefault('results_wrapper_class', SARIMAXResultsWrapper)
# --> 868         return super(SARIMAX, self).smooth(params, **kwargs)
#     869
#     870     @staticmethod
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in smooth(self, params, transformed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     559
#     560         # Get the state space output
# --> 561         result = self.ssm.smooth(complex_step=complex_step, **kwargs)
#     562
#     563         # Wrap in a results object
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_smoother.py in smooth(self, smoother_output, results, run_filter, prefix, complex_step, **kwargs)
#     481             results.update_representation(self)
#     482         if run_filter:
# --> 483             results.update_filter(kfilter)
#     484
#     485         # Run the smoother and update the output
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in update_filter(self, kalman_filter)
#    1218         self.filtered_state = np.array(kalman_filter.filtered_state, copy=True)
#    1219         self.filtered_state_cov = np.array(
# -> 1220             kalman_filter.filtered_state_cov, copy=True
#    1221         )
#    1222         self.predicted_state = np.array(
#
# KeyboardInterrupt:

# %%
print("best[aic] parameter ********")
print(test_results[test_results.aic == min(test_results.aic)])
print(test_results[test_results.aic == max(test_results.aic)])

# %%
# SRIMAモデル（ちょっとだけパラメータ最適化・総当たりaicベストを適用）
sarimax_optimization = sm.tsa.SARIMAX(diff, 
                        order=(2, 0, 3),
                        seasonal_order=(0, 0, 0, 17),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()

sarimax_optimization_resid = sarimax_optimization.resid # 残差成分

fig = plt.figure(figsize=(8, 8))


# 自己相関(ACF)のグラフ
ax1 = fig.add_subplot(211)
sm.graphics.tsa.plot_acf(sarimax_optimization_resid, lags=40, ax=ax1) #ACF計算とグラフ自動作成

# 偏自己相関(PACF)のグラフ
ax2 = fig.add_subplot(212)
sm.graphics.tsa.plot_pacf(sarimax_optimization_resid, lags=40, ax=ax2) #PACF計算とグラフ自動作成

plt.tight_layout() # グラフ間スキマ調整

# %%
passengers_train = df_bitcoin[df_bitcoin['日付開始']<'2018-05-22']
passengers_train = passengers_train[['pct_1d','日付開始']]
passengers_train=passengers_train.reset_index()
passengers_train=passengers_train.drop('index',axis=1)
passengers_train=passengers_train.set_index(keys='日付開始')
print(passengers_train.head())
print(passengers_train.tail())
print(passengers_train.isnull().sum())
# Out:
#               pct_1d
# 日付開始
# 2018-05-21  0.012169
# 2018-05-20 -0.032308
# 2018-05-19  0.001060
# 2018-05-18 -0.019853
# 2018-05-17  0.034383
#               pct_1d
# 日付開始
# 2013-05-02  0.095341
# 2013-05-01  0.194363
# 2013-04-30  0.035971
# 2013-04-29 -0.066389
# 2013-04-28  0.006397
# pct_1d    0
# dtype: int64

# %%
passengers_test = df_bitcoin[df_bitcoin['日付開始']>='2018-05-22']
passengers_test = passengers_test[['pct_1d','日付開始']]
passengers_test=passengers_test.reset_index()
passengers_test=passengers_test.drop('index',axis=1)
passengers_test=passengers_test.set_index(keys='日付開始')
passengers_test = passengers_test['pct_1d'].dropna()
print(passengers_test.head())
print(passengers_test.tail())
print(passengers_test.isnull().sum())
# Out:
# 日付開始
# 2018-08-21   -0.028550
# 2018-08-20    0.031652
# 2018-08-19   -0.011990
# 2018-08-18    0.025046
# 2018-08-17   -0.036838
# Name: pct_1d, dtype: float64
# 日付開始
# 2018-05-26    0.016897
# 2018-05-25    0.014135
# 2018-05-24   -0.004107
# 2018-05-23    0.062948
# 2018-05-22    0.047628
# Name: pct_1d, dtype: float64
# 0

# %%
# SRIMAモデル（テストデータを2年分除いてモデル作成）
sarimax_train = sm.tsa.SARIMAX(passengers_train, 
                        order=(2, 0, 3),
                        seasonal_order=(0, 0, 0, 17),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()

# %%
sarimax_train_pred = sarimax_train.predict() # テストデータ2年分予測
sarimax_train_pred
# Out:
# 2018-05-21    0.000000
# 2018-05-20    0.008955
# 2018-05-19   -0.035619
# 2018-05-18    0.032223
# 2018-05-17   -0.015641
# 2018-05-16    0.015191
# 2018-05-15   -0.002542
# 2018-05-14   -0.012896
# 2018-05-13   -0.015700
# 2018-05-12   -0.003578
# 2018-05-11    0.013842
# 2018-05-10    0.018350
# 2018-05-09   -0.009203
# 2018-05-08   -0.027038
# 2018-05-07   -0.008605
# 2018-05-06    0.015986
# 2018-05-05    0.015314
# 2018-05-04   -0.006190
# 2018-05-03   -0.016192
# 2018-05-02   -0.007149
# 2018-05-01    0.012997
# 2018-04-30    0.017382
# 2018-04-29   -0.000028
# 2018-04-28   -0.017256
# 2018-04-27   -0.012548
# 2018-04-26    0.010415
# 2018-04-25    0.015767
# 2018-04-24    0.005879
# 2018-04-23   -0.016545
# 2018-04-22   -0.013560
#                 ...
# 2013-05-27    0.001517
# 2013-05-26   -0.004072
# 2013-05-25   -0.005130
# 2013-05-24    0.000216
# 2013-05-23    0.004729
# 2013-05-22    0.004297
# 2013-05-21   -0.000564
# 2013-05-20   -0.004183
# 2013-05-19   -0.002276
# 2013-05-18    0.002276
# 2013-05-17    0.003648
# 2013-05-16    0.000273
# 2013-05-15   -0.002374
# 2013-05-14   -0.000980
# 2013-05-13    0.002518
# 2013-05-12    0.001471
# 2013-05-11   -0.001070
# 2013-05-10   -0.002098
# 2013-05-09   -0.001099
# 2013-05-08    0.002040
# 2013-05-07    0.002623
# 2013-05-06    0.000766
# 2013-05-05   -0.002165
# 2013-05-04   -0.003312
# 2013-05-03   -0.000368
# 2013-05-02    0.006338
# 2013-05-01    0.004207
# 2013-04-30   -0.005118
# 2013-04-29   -0.012747
# 2013-04-28   -0.006786
# Freq: -1D, Length: 1850, dtype: float64

# %%
sarimax_train_pred.head()
# Out:
# 2018-05-21    0.000000
# 2018-05-20    0.008955
# 2018-05-19   -0.035619
# 2018-05-18    0.032223
# 2018-05-17   -0.015641
# Freq: -1D, dtype: float64

# %%
plt.figure(figsize=(8, 8))

plt.plot(df_bitcoin['日付開始'],df_bitcoin['pct_1d'],label="original")
plt.plot(sarimax_train_pred, c="b", label="model-pred")
plt.legend(loc='best')

# %% [markdown]
# ## 一か月後のやつを見てみる

# %%
plt.figure(figsize=(7, 20))

diff = df_bitcoin['pct_30d'].dropna()
sm.graphics.tsa.plot_acf(diff, lags=60)
plt.show()

# %%
plt.figure(figsize=(7, 20))

diff = df_bitcoin['pct_30d'].dropna()
sm.graphics.tsa.plot_pacf(diff, lags=70)
plt.show()

# %%
# ADF検定（原型列で確認だけ）
res_ctt = sm.tsa.stattools.adfuller(diff, regression="ctt") # トレンド項あり（２次）、定数項あり
res_ct = sm.tsa.stattools.adfuller(diff, regression="ct") # トレンド項あり（１次）、定数項あり
res_c = sm.tsa.stattools.adfuller(diff, regression="c") # トレンド項なし、定数項あり
res_nc = sm.tsa.stattools.adfuller(diff, regression="nc") # トレンド項なし、定数項なし
print(res_ctt)
print(res_ct)
print(res_c)
print(res_nc)
# Out:
# (-7.347654590300572, 1.2366727482706074e-08, 22, 1890, {'1%': -4.377271399665307, '5%': -3.835518223057621, '10%': -3.5551977874721032}, -4961.38844657181)
# (-7.334073262050012, 2.4502405546443083e-09, 22, 1890, {'1%': -3.9635679782149102, '5%': -3.412815499288208, '10%': -3.1284191444364016}, -4963.122521212751)
# (-7.3169122824495485, 1.222484333410566e-10, 22, 1890, {'1%': -3.433814658052138, '5%': -2.8630704504871605, '10%': -2.56758475462613}, -4964.8438326752375)
# (-7.261557612948949, 1.5637956181300203e-11, 22, 1890, {'1%': -2.5669239783320736, '5%': -1.941143053800256, '10%': -1.6166802269197094}, -4966.019230259631)

# %%
diff=diff.values.tolist()

# %%
res_selection = sm.tsa.arma_order_select_ic(diff, ic='aic', trend='nc')
res_selection
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# {'aic':              0            1            2
#  0          NaN -1893.620555 -3008.783580
#  1 -5017.066818 -5015.385987 -5013.699824
#  2 -5015.377545 -5021.922538 -5020.900603
#  3 -5013.686023 -5020.894539 -5021.848386
#  4 -5011.890461 -5010.873344 -5022.981070, 'aic_min_order': (4, 2)}

# %%
sarimax = sm.tsa.SARIMAX(diff, 
                        order=(4, 1, 2),
                        seasonal_order=(1, 1, 1, 31),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
sarimax_resid = sarimax.resid # モデルの残差成分

# %%
# モデル残差のコレログラム
fig = plt.figure(figsize=(8, 8))

# 自己相関(ACF)のグラフ
ax1 = fig.add_subplot(211)
sm.graphics.tsa.plot_acf(sarimax_resid, lags=50, ax=ax1) #ACF計算とグラフ自動作成

# 偏自己相関(PACF)のグラフ
ax2 = fig.add_subplot(212)
sm.graphics.tsa.plot_pacf(sarimax_resid, lags=50, ax=ax2) #PACF計算とグラフ自動作成

plt.tight_layout() # グラフ間スキマ調整

# %%
# SRIMAモデル（試しに）季節調整なし
sarimax_noseasonal = sm.tsa.SARIMAX(diff, 
                        order=(2, 1, 2),
                        seasonal_order=(0, 0, 0, 0),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()

sarimax_noseasonal_resid = sarimax_noseasonal.resid # 残差成分

fig = plt.figure(figsize=(8, 8))

# 自己相関(ACF)のグラフ
ax1 = fig.add_subplot(211)
sm.graphics.tsa.plot_acf(sarimax_noseasonal_resid, lags=50, ax=ax1) #ACF計算とグラフ自動作成

# 偏自己相関(PACF)のグラフ
ax2 = fig.add_subplot(212)
sm.graphics.tsa.plot_pacf(sarimax_noseasonal_resid, lags=50, ax=ax2) #PACF計算とグラフ自動作成

plt.tight_layout() # グラフ間スキマ調整

# %%
print(sarimax.aic) 
print(sarimax_noseasonal.aic)
# Out:
# -4666.195785436377
# -4970.643671798221

# %%
# SARIMAパラメター最適化（総当たりチェック）


# パラメータ範囲
# order(p, d, q)
min_p = 1; max_p = 5 # min_pは1以上を指定しないとエラー
min_d = 0; max_d = 1
min_q = 0; max_q = 3 

# seasonal_order(sp, sd, sq)
min_sp = 0; max_sp = 1
min_sd = 0; max_sd = 1
min_sq = 0; max_sq = 1

test_pattern = (max_p - min_p +1)*(max_q - min_q + 1)*(max_d - min_d + 1)*(max_sp - min_sp + 1)*(max_sq - min_sq + 1)*(max_sd - min_sd + 1)
print("pattern:", test_pattern)

sfq = 12 # seasonal_order周期パラメータ
ts = diff # 時系列データ

test_results = pd.DataFrame(index=range(test_pattern), columns=["model_parameters", "aic"])
num = 0
for p in range(min_p, max_p + 1):
    for d in range(min_d, max_d + 1):
        for q in range(min_q, max_q + 1):
            for sp in range(min_sp, max_sp + 1):
                for sd in range(min_sd, max_sd + 1):
                    for sq in range(min_sq, max_sq + 1):
                        sarima = sm.tsa.SARIMAX(
                            ts, order=(p, d, q), 
                            seasonal_order=(sp, sd, sq, sfq), 
                            enforce_stationarity = False, 
                            enforce_invertibility = False
                        ).fit()
                        test_results.iloc[num]["model_parameters"] = "order=(" + str(p) + ","+ str(d) + ","+ str(q) + "), seasonal_order=("+ str(sp) + ","+ str(sd) + "," + str(sq) + ")"
                        test_results.iloc[num]["aic"] = sarima.aic
                        print(num,'/', test_pattern-1, test_results.iloc[num]["model_parameters"],  test_results.iloc[num]["aic"] )
                        num = num + 1

# 結果（最小AiC）
print("best[aic] parameter ********")
print(test_results[test_results.aic == min(test_results.aic)])
# Out:
# pattern: 320
# 0 / 319 order=(1,0,0), seasonal_order=(0,0,0) -5016.432571164206
# 1 / 319 order=(1,0,0), seasonal_order=(0,0,1) -4979.059100963236
# 2 / 319 order=(1,0,0), seasonal_order=(0,1,0) -3642.139713272114
# 3 / 319 order=(1,0,0), seasonal_order=(0,1,1) -4889.606995903729
# 4 / 319 order=(1,0,0), seasonal_order=(1,0,0) -4978.495798777365
# 5 / 319 order=(1,0,0), seasonal_order=(1,0,1) -4979.372830419292
# 6 / 319 order=(1,0,0), seasonal_order=(1,1,0) -4099.6596975637085
# 7 / 319 order=(1,0,0), seasonal_order=(1,1,1) -4884.87874524264
# 8 / 319 order=(1,0,1), seasonal_order=(0,0,0) -5011.478820627033
# 9 / 319 order=(1,0,1), seasonal_order=(0,0,1) -4976.354935937585
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 10 / 319 order=(1,0,1), seasonal_order=(0,1,0) -3639.4587109881595
# 11 / 319 order=(1,0,1), seasonal_order=(0,1,1) -4884.769086152205
# 12 / 319 order=(1,0,1), seasonal_order=(1,0,0) -4976.827960768474
# 13 / 319 order=(1,0,1), seasonal_order=(1,0,1) -4976.470141638976
# 14 / 319 order=(1,0,1), seasonal_order=(1,1,0) -4097.923959628284
# 15 / 319 order=(1,0,1), seasonal_order=(1,1,1) -4880.874659490222
# 16 / 319 order=(1,0,2), seasonal_order=(0,0,0) -5006.551136694269
# 17 / 319 order=(1,0,2), seasonal_order=(0,0,1) -4972.050725571358
# 18 / 319 order=(1,0,2), seasonal_order=(0,1,0) -3634.664858523558
# 19 / 319 order=(1,0,2), seasonal_order=(0,1,1) -4880.2915847943
# 20 / 319 order=(1,0,2), seasonal_order=(1,0,0) -4975.228002091586
# 21 / 319 order=(1,0,2), seasonal_order=(1,0,1) -4971.691885422564
# 22 / 319 order=(1,0,2), seasonal_order=(1,1,0) -4096.80193926358
# 23 / 319 order=(1,0,2), seasonal_order=(1,1,1) -4876.811046748889
# 24 / 319 order=(1,0,3), seasonal_order=(0,0,0) -5001.3483294121515
# 25 / 319 order=(1,0,3), seasonal_order=(0,0,1) -4966.689867758296
# 26 / 319 order=(1,0,3), seasonal_order=(0,1,0) -3632.1333501771705
# 27 / 319 order=(1,0,3), seasonal_order=(0,1,1) -4874.640869301664
# 28 / 319 order=(1,0,3), seasonal_order=(1,0,0) -4973.402553694476
# 29 / 319 order=(1,0,3), seasonal_order=(1,0,1) -4966.47751374703
# 30 / 319 order=(1,0,3), seasonal_order=(1,1,0) -4094.856593462764
# 31 / 319 order=(1,0,3), seasonal_order=(1,1,1) -4872.052269501151
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 32 / 319 order=(1,1,0), seasonal_order=(0,0,0) -4980.242733156636
# 33 / 319 order=(1,1,0), seasonal_order=(0,0,1) -4947.698402635453
# 34 / 319 order=(1,1,0), seasonal_order=(0,1,0) -3545.6724554555194
# 35 / 319 order=(1,1,0), seasonal_order=(0,1,1) -4853.154573711913
# 36 / 319 order=(1,1,0), seasonal_order=(1,0,0) -4946.843325840013
# 37 / 319 order=(1,1,0), seasonal_order=(1,0,1) -4948.565973629789
# 38 / 319 order=(1,1,0), seasonal_order=(1,1,0) -4039.072897234729
# 39 / 319 order=(1,1,0), seasonal_order=(1,1,1) -4851.858364614006
# 40 / 319 order=(1,1,1), seasonal_order=(0,0,0) -5001.5301516807995
# 41 / 319 order=(1,1,1), seasonal_order=(0,0,1) -4966.51776022491
# 42 / 319 order=(1,1,1), seasonal_order=(0,1,0) -3627.845272846266
# 43 / 319 order=(1,1,1), seasonal_order=(0,1,1) -4850.537490508848
# 44 / 319 order=(1,1,1), seasonal_order=(1,0,0) -4965.72103676418
# 45 / 319 order=(1,1,1), seasonal_order=(1,0,1) -4965.533688742674
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 46 / 319 order=(1,1,1), seasonal_order=(1,1,0) -4039.6037666278235
# 47 / 319 order=(1,1,1), seasonal_order=(1,1,1) -4849.613363551804
# 48 / 319 order=(1,1,2), seasonal_order=(0,0,0) -4972.316000235751
# 49 / 319 order=(1,1,2), seasonal_order=(0,0,1) -4940.356225587908
# 50 / 319 order=(1,1,2), seasonal_order=(0,1,0) -3540.6527541734645
# 51 / 319 order=(1,1,2), seasonal_order=(0,1,1) -4846.066033402414
# 52 / 319 order=(1,1,2), seasonal_order=(1,0,0) -4944.702408604631
# 53 / 319 order=(1,1,2), seasonal_order=(1,0,1) -4940.599421164543
# 54 / 319 order=(1,1,2), seasonal_order=(1,1,0) -4040.756890999359
# 55 / 319 order=(1,1,2), seasonal_order=(1,1,1) -4845.3133652982515
# 56 / 319 order=(1,1,3), seasonal_order=(0,0,0) -4967.218219560138
# 57 / 319 order=(1,1,3), seasonal_order=(0,0,1) -4935.449651097091
# 58 / 319 order=(1,1,3), seasonal_order=(0,1,0) -3535.6417041441196
# 59 / 319 order=(1,1,3), seasonal_order=(0,1,1) -4842.514059821503
# 60 / 319 order=(1,1,3), seasonal_order=(1,0,0) -4944.117387156506
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 61 / 319 order=(1,1,3), seasonal_order=(1,0,1) -4935.628534667267
# 62 / 319 order=(1,1,3), seasonal_order=(1,1,0) -4045.164083743055
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 63 / 319 order=(1,1,3), seasonal_order=(1,1,1) -4842.913375408909
# 64 / 319 order=(2,0,0), seasonal_order=(0,0,0) -5011.480404019271
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 65 / 319 order=(2,0,0), seasonal_order=(0,0,1) -4977.446892492844
# 66 / 319 order=(2,0,0), seasonal_order=(0,1,0) -3639.471329801318
# 67 / 319 order=(2,0,0), seasonal_order=(0,1,1) -4887.606006497435
# 68 / 319 order=(2,0,0), seasonal_order=(1,0,0) -4975.818848777764
# 69 / 319 order=(2,0,0), seasonal_order=(1,0,1) -4976.486967276649
# 70 / 319 order=(2,0,0), seasonal_order=(1,1,0) -4095.224042386838
# 71 / 319 order=(2,0,0), seasonal_order=(1,1,1) -4880.86773422757
# 72 / 319 order=(2,0,1), seasonal_order=(0,0,0) -4999.7541639023075
# 73 / 319 order=(2,0,1), seasonal_order=(0,0,1) -4973.778962877947
# 74 / 319 order=(2,0,1), seasonal_order=(0,1,0) -3637.5689844998915
# 75 / 319 order=(2,0,1), seasonal_order=(0,1,1) -4882.782519759872
# 76 / 319 order=(2,0,1), seasonal_order=(1,0,0) -4973.283759102462
# 77 / 319 order=(2,0,1), seasonal_order=(1,0,1) -4973.570293211089
# 78 / 319 order=(2,0,1), seasonal_order=(1,1,0) -4093.1240781146516
# 79 / 319 order=(2,0,1), seasonal_order=(1,1,1) -4878.947509099238
# 80 / 319 order=(2,0,2), seasonal_order=(0,0,0) -5005.37107812773
# 81 / 319 order=(2,0,2), seasonal_order=(0,0,1) -4969.893883610622
# 82 / 319 order=(2,0,2), seasonal_order=(0,1,0) -3682.3774511783577
# 83 / 319 order=(2,0,2), seasonal_order=(0,1,1) -4877.756301776668
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 84 / 319 order=(2,0,2), seasonal_order=(1,0,0) -4972.627366251623
# 85 / 319 order=(2,0,2), seasonal_order=(1,0,1) -4969.468749243218
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 86 / 319 order=(2,0,2), seasonal_order=(1,1,0) -4146.344617150165
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 87 / 319 order=(2,0,2), seasonal_order=(1,1,1) -4878.278258132249
# 88 / 319 order=(2,0,3), seasonal_order=(0,0,0) -4998.818765043718
# 89 / 319 order=(2,0,3), seasonal_order=(0,0,1) -4964.371608648599
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 90 / 319 order=(2,0,3), seasonal_order=(0,1,0) -3671.824412540809
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 91 / 319 order=(2,0,3), seasonal_order=(0,1,1) -4875.363446287388
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 92 / 319 order=(2,0,3), seasonal_order=(1,0,0) -4968.873332332576
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 93 / 319 order=(2,0,3), seasonal_order=(1,0,1) -4964.12151957541
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 94 / 319 order=(2,0,3), seasonal_order=(1,1,0) -4151.711343872474
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 95 / 319 order=(2,0,3), seasonal_order=(1,1,1) -4872.25029213021
# 96 / 319 order=(2,1,0), seasonal_order=(0,0,0) -4976.781560453617
# 97 / 319 order=(2,1,0), seasonal_order=(0,0,1) -4947.330527332409
# 98 / 319 order=(2,1,0), seasonal_order=(0,1,0) -3544.772660276085
# 99 / 319 order=(2,1,0), seasonal_order=(0,1,1) -4852.625205382981
# 100 / 319 order=(2,1,0), seasonal_order=(1,0,0) -4943.894185441055
# 101 / 319 order=(2,1,0), seasonal_order=(1,0,1) -4944.9371846850845
# 102 / 319 order=(2,1,0), seasonal_order=(1,1,0) -4039.4577897758545
# 103 / 319 order=(2,1,0), seasonal_order=(1,1,1) -4849.257901227655
# 104 / 319 order=(2,1,1), seasonal_order=(0,0,0) -4998.785298599099
# 105 / 319 order=(2,1,1), seasonal_order=(0,0,1) -4964.8037774359045
# 106 / 319 order=(2,1,1), seasonal_order=(0,1,0) -3543.162944430075
# 107 / 319 order=(2,1,1), seasonal_order=(0,1,1) -4849.048673116558
# 108 / 319 order=(2,1,1), seasonal_order=(1,0,0) -4942.295387259799
# 109 / 319 order=(2,1,1), seasonal_order=(1,0,1) -4944.098333268888
# 110 / 319 order=(2,1,1), seasonal_order=(1,1,0) -4038.434674456791
# 111 / 319 order=(2,1,1), seasonal_order=(1,1,1) -4848.29331167907
# 112 / 319 order=(2,1,2), seasonal_order=(0,0,0) -4970.643671798221
# 113 / 319 order=(2,1,2), seasonal_order=(0,0,1) -4937.631888951563
# 114 / 319 order=(2,1,2), seasonal_order=(0,1,0) -3538.5663240538897
# 115 / 319 order=(2,1,2), seasonal_order=(0,1,1) -4844.006819723115
# 116 / 319 order=(2,1,2), seasonal_order=(1,0,0) -4940.10147458792
# 117 / 319 order=(2,1,2), seasonal_order=(1,0,1) -4936.351505013307
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 118 / 319 order=(2,1,2), seasonal_order=(1,1,0) -4081.841728134231
# 119 / 319 order=(2,1,2), seasonal_order=(1,1,1) -4843.48759089779
# 120 / 319 order=(2,1,3), seasonal_order=(0,0,0) -4965.4963297549275
# 121 / 319 order=(2,1,3), seasonal_order=(0,0,1) -4933.49829232903
# 122 / 319 order=(2,1,3), seasonal_order=(0,1,0) -3533.7035032245167
# 123 / 319 order=(2,1,3), seasonal_order=(0,1,1) -4840.556677378563
# 124 / 319 order=(2,1,3), seasonal_order=(1,0,0) -4939.298355835262
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 125 / 319 order=(2,1,3), seasonal_order=(1,0,1) -4933.82833629094
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 126 / 319 order=(2,1,3), seasonal_order=(1,1,0) -4133.374291384134
# 127 / 319 order=(2,1,3), seasonal_order=(1,1,1) -4840.918511579737
# 128 / 319 order=(3,0,0), seasonal_order=(0,0,0) -5006.530051515038
# 129 / 319 order=(3,0,0), seasonal_order=(0,0,1) -4975.782303860447
# 130 / 319 order=(3,0,0), seasonal_order=(0,1,0) -3634.6949813346337
# 131 / 319 order=(3,0,0), seasonal_order=(0,1,1) -4884.872180638074
# 132 / 319 order=(3,0,0), seasonal_order=(1,0,0) -4971.498287414382
# 133 / 319 order=(3,0,0), seasonal_order=(1,0,1) -4971.669879739817
# 134 / 319 order=(3,0,0), seasonal_order=(1,1,0) -4091.2382725131
# 135 / 319 order=(3,0,0), seasonal_order=(1,1,1) -4876.795380465459
# 136 / 319 order=(3,0,1), seasonal_order=(0,0,0) -5004.585693672577
# 137 / 319 order=(3,0,1), seasonal_order=(0,0,1) -4973.13545552361
# 138 / 319 order=(3,0,1), seasonal_order=(0,1,0) -3632.7171476798358
# 139 / 319 order=(3,0,1), seasonal_order=(0,1,1) -4880.847915860255
# 140 / 319 order=(3,0,1), seasonal_order=(1,0,0) -4969.093767362114
# 141 / 319 order=(3,0,1), seasonal_order=(1,0,1) -4969.223873089303
# 142 / 319 order=(3,0,1), seasonal_order=(1,1,0) -4089.299899505423
# 143 / 319 order=(3,0,1), seasonal_order=(1,1,1) -4874.615538280252
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 144 / 319 order=(3,0,2), seasonal_order=(0,0,0) -5006.585511705359
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 145 / 319 order=(3,0,2), seasonal_order=(0,0,1) -4955.231507913623
# 146 / 319 order=(3,0,2), seasonal_order=(0,1,0) -3680.292390824401
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 147 / 319 order=(3,0,2), seasonal_order=(0,1,1) -4877.47471259763
# 148 / 319 order=(3,0,2), seasonal_order=(1,0,0) -4967.712527433059
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 149 / 319 order=(3,0,2), seasonal_order=(1,0,1) -4960.954500503614
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 150 / 319 order=(3,0,2), seasonal_order=(1,1,0) -4140.948546548132
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 151 / 319 order=(3,0,2), seasonal_order=(1,1,1) -4873.38032572856
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 152 / 319 order=(3,0,3), seasonal_order=(0,0,0) -4966.17461812846
# 153 / 319 order=(3,0,3), seasonal_order=(0,0,1) -4469.232139606844
# 154 / 319 order=(3,0,3), seasonal_order=(0,1,0) -3677.487533578962
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 155 / 319 order=(3,0,3), seasonal_order=(0,1,1) -4871.524460600364
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 156 / 319 order=(3,0,3), seasonal_order=(1,0,0) -4915.480341395569
# 157 / 319 order=(3,0,3), seasonal_order=(1,0,1) -4864.657695340483
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 158 / 319 order=(3,0,3), seasonal_order=(1,1,0) -4144.919494004287
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 159 / 319 order=(3,0,3), seasonal_order=(1,1,1) -4867.359929889382
# 160 / 319 order=(3,1,0), seasonal_order=(0,0,0) -4972.750827079458
# 161 / 319 order=(3,1,0), seasonal_order=(0,0,1) -4946.79827637507
# 162 / 319 order=(3,1,0), seasonal_order=(0,1,0) -3540.392418123128
# 163 / 319 order=(3,1,0), seasonal_order=(0,1,1) -4851.080429778131
# 164 / 319 order=(3,1,0), seasonal_order=(1,0,0) -4939.771995795205
# 165 / 319 order=(3,1,0), seasonal_order=(1,0,1) -4940.962137580022
# 166 / 319 order=(3,1,0), seasonal_order=(1,1,0) -4035.3098146514867
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 167 / 319 order=(3,1,0), seasonal_order=(1,1,1) -4845.759050505669
# 168 / 319 order=(3,1,1), seasonal_order=(0,0,0) -4970.770714622983
# 169 / 319 order=(3,1,1), seasonal_order=(0,0,1) -4942.360414753973
# 170 / 319 order=(3,1,1), seasonal_order=(0,1,0) -3538.3989560675827
# 171 / 319 order=(3,1,1), seasonal_order=(0,1,1) -4846.819225810783
# 172 / 319 order=(3,1,1), seasonal_order=(1,0,0) -4938.04059389258
# 173 / 319 order=(3,1,1), seasonal_order=(1,0,1) -4939.235587505737
# 174 / 319 order=(3,1,1), seasonal_order=(1,1,0) -4033.638345638835
# 175 / 319 order=(3,1,1), seasonal_order=(1,1,1) -4843.79248931829
# 176 / 319 order=(3,1,2), seasonal_order=(0,0,0) -4966.865623087289
# 177 / 319 order=(3,1,2), seasonal_order=(0,0,1) -4936.961721056222
# 178 / 319 order=(3,1,2), seasonal_order=(0,1,0) -3622.947104137187
# 179 / 319 order=(3,1,2), seasonal_order=(0,1,1) -4859.37095667386
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 180 / 319 order=(3,1,2), seasonal_order=(1,0,0) -4935.599462652985
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 181 / 319 order=(3,1,2), seasonal_order=(1,0,1) -4955.391241870975
# 182 / 319 order=(3,1,2), seasonal_order=(1,1,0) -4076.8472096640385
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 183 / 319 order=(3,1,2), seasonal_order=(1,1,1) -4840.645606716857
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 184 / 319 order=(3,1,3), seasonal_order=(0,0,0) -4997.379291910089
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 185 / 319 order=(3,1,3), seasonal_order=(0,0,1) -4944.583734974962
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 186 / 319 order=(3,1,3), seasonal_order=(0,1,0) -3718.5628470216325
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 187 / 319 order=(3,1,3), seasonal_order=(0,1,1) -4866.499587223874
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 188 / 319 order=(3,1,3), seasonal_order=(1,0,0) -4966.7641897746835
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 189 / 319 order=(3,1,3), seasonal_order=(1,0,1) -4960.702849139791
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 190 / 319 order=(3,1,3), seasonal_order=(1,1,0) -4093.5583321405056
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 191 / 319 order=(3,1,3), seasonal_order=(1,1,1) -4864.85384083122
# 192 / 319 order=(4,0,0), seasonal_order=(0,0,0) -5001.414656286275
# 193 / 319 order=(4,0,0), seasonal_order=(0,0,1) -4974.060722781527
# 194 / 319 order=(4,0,0), seasonal_order=(0,1,0) -3632.9272603850177
# 195 / 319 order=(4,0,0), seasonal_order=(0,1,1) -4882.886050223982
# 196 / 319 order=(4,0,0), seasonal_order=(1,0,0) -4966.203907000558
# 197 / 319 order=(4,0,0), seasonal_order=(1,0,1) -4966.5425484187235
# 198 / 319 order=(4,0,0), seasonal_order=(1,1,0) -4086.216085910565
# 199 / 319 order=(4,0,0), seasonal_order=(1,1,1) -4872.115074652289
# 200 / 319 order=(4,0,1), seasonal_order=(0,0,0) -4999.558779942046
# 201 / 319 order=(4,0,1), seasonal_order=(0,0,1) -4971.503529222127
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 202 / 319 order=(4,0,1), seasonal_order=(0,1,0) -3679.5439871610088
# 203 / 319 order=(4,0,1), seasonal_order=(0,1,1) -4878.232111275189
# 204 / 319 order=(4,0,1), seasonal_order=(1,0,0) -4963.936688339021
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 205 / 319 order=(4,0,1), seasonal_order=(1,0,1) -4964.184477111252
# 206 / 319 order=(4,0,1), seasonal_order=(1,1,0) -4084.1785457963097
# 207 / 319 order=(4,0,1), seasonal_order=(1,1,1) -4870.049602562212
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 208 / 319 order=(4,0,2), seasonal_order=(0,0,0) -3228.140649234331
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 209 / 319 order=(4,0,2), seasonal_order=(0,0,1) -3101.1401502124318
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 210 / 319 order=(4,0,2), seasonal_order=(0,1,0) -3677.019549011803
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 211 / 319 order=(4,0,2), seasonal_order=(0,1,1) -4873.561414259848
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 212 / 319 order=(4,0,2), seasonal_order=(1,0,0) -3298.365166448332
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 213 / 319 order=(4,0,2), seasonal_order=(1,0,1) -3488.724921040054
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 214 / 319 order=(4,0,2), seasonal_order=(1,1,0) -4133.6772955431825
# 215 / 319 order=(4,0,2), seasonal_order=(1,1,1) -4868.284400710728
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 216 / 319 order=(4,0,3), seasonal_order=(0,0,0) -5005.679873070626
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 217 / 319 order=(4,0,3), seasonal_order=(0,0,1) -4754.702014205963
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 218 / 319 order=(4,0,3), seasonal_order=(0,1,0) -3675.3037792067553
# 219 / 319 order=(4,0,3), seasonal_order=(0,1,1) -4867.9468749441185
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 220 / 319 order=(4,0,3), seasonal_order=(1,0,0) -4885.88122379662
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 221 / 319 order=(4,0,3), seasonal_order=(1,0,1) -4465.5984855970255
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 222 / 319 order=(4,0,3), seasonal_order=(1,1,0) -4138.342113629198
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 223 / 319 order=(4,0,3), seasonal_order=(1,1,1) -4865.869380252425
# 224 / 319 order=(4,1,0), seasonal_order=(0,0,0) -4968.1710211872705
# 225 / 319 order=(4,1,0), seasonal_order=(0,0,1) -4945.482033595519
# 226 / 319 order=(4,1,0), seasonal_order=(0,1,0) -3535.9258378707186
# 227 / 319 order=(4,1,0), seasonal_order=(0,1,1) -4849.242743859303
# 228 / 319 order=(4,1,0), seasonal_order=(1,0,0) -4935.285052453355
# 229 / 319 order=(4,1,0), seasonal_order=(1,0,1) -4936.295864507541
# 230 / 319 order=(4,1,0), seasonal_order=(1,1,0) -4032.062919217944
# 231 / 319 order=(4,1,0), seasonal_order=(1,1,1) -4841.570478557142
# 232 / 319 order=(4,1,1), seasonal_order=(0,0,0) -4966.142906305308
# 233 / 319 order=(4,1,1), seasonal_order=(0,0,1) -4940.916983119274
# 234 / 319 order=(4,1,1), seasonal_order=(0,1,0) -3533.9311242137824
# 235 / 319 order=(4,1,1), seasonal_order=(0,1,1) -4845.029661821107
# 236 / 319 order=(4,1,1), seasonal_order=(1,0,0) -4933.264620966039
# 237 / 319 order=(4,1,1), seasonal_order=(1,0,1) -4934.380559503838
# 238 / 319 order=(4,1,1), seasonal_order=(1,1,0) -4030.1228037773103
# 239 / 319 order=(4,1,1), seasonal_order=(1,1,1) -4839.615245990929
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 240 / 319 order=(4,1,2), seasonal_order=(0,0,0) -4964.297637995232
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 241 / 319 order=(4,1,2), seasonal_order=(0,0,1) -4927.463617179659
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 242 / 319 order=(4,1,2), seasonal_order=(0,1,0) -3626.8316072556636
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 243 / 319 order=(4,1,2), seasonal_order=(0,1,1) -4801.14338908174
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 244 / 319 order=(4,1,2), seasonal_order=(1,0,0) -4930.750595971843
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 245 / 319 order=(4,1,2), seasonal_order=(1,0,1) -4928.574172954726
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 246 / 319 order=(4,1,2), seasonal_order=(1,1,0) -4075.9494047884164
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 247 / 319 order=(4,1,2), seasonal_order=(1,1,1) -4837.4533669566445
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 248 / 319 order=(4,1,3), seasonal_order=(0,0,0) -5013.50731923917
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 249 / 319 order=(4,1,3), seasonal_order=(0,0,1) -4970.795097012346
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 250 / 319 order=(4,1,3), seasonal_order=(0,1,0) -3705.3209655303117
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 251 / 319 order=(4,1,3), seasonal_order=(0,1,1) -4864.000157646827
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 252 / 319 order=(4,1,3), seasonal_order=(1,0,0) -4970.645323776747
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 253 / 319 order=(4,1,3), seasonal_order=(1,0,1) -4968.071335222252
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 254 / 319 order=(4,1,3), seasonal_order=(1,1,0) -4144.26165365489
# 255 / 319 order=(4,1,3), seasonal_order=(1,1,1) -4856.852895001534
# 256 / 319 order=(5,0,0), seasonal_order=(0,0,0) -4996.109332866747
# 257 / 319 order=(5,0,0), seasonal_order=(0,0,1) -4972.094608193222
# 258 / 319 order=(5,0,0), seasonal_order=(0,1,0) -3630.45468631132
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 259 / 319 order=(5,0,0), seasonal_order=(0,1,1) -4880.942813539967
# 260 / 319 order=(5,0,0), seasonal_order=(1,0,0) -4961.050743429991
# 261 / 319 order=(5,0,0), seasonal_order=(1,0,1) -4961.289143567763
# 262 / 319 order=(5,0,0), seasonal_order=(1,1,0) -4081.0703627666276
# 263 / 319 order=(5,0,0), seasonal_order=(1,1,1) -4867.222562259618
# 264 / 319 order=(5,0,1), seasonal_order=(0,0,0) -4994.327171505289
# 265 / 319 order=(5,0,1), seasonal_order=(0,0,1) -4969.627664355263
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 266 / 319 order=(5,0,1), seasonal_order=(0,1,0) -3675.024541892816
# 267 / 319 order=(5,0,1), seasonal_order=(0,1,1) -4876.257436190892
# 268 / 319 order=(5,0,1), seasonal_order=(1,0,0) -4958.992382749521
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 269 / 319 order=(5,0,1), seasonal_order=(1,0,1) -4959.27252514642
# 270 / 319 order=(5,0,1), seasonal_order=(1,1,0) -4079.1251818652563
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 271 / 319 order=(5,0,1), seasonal_order=(1,1,1) -4865.19744029629
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 272 / 319 order=(5,0,2), seasonal_order=(0,0,0) -4993.032668855643
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 273 / 319 order=(5,0,2), seasonal_order=(0,0,1) -4965.255187778949
# 274 / 319 order=(5,0,2), seasonal_order=(0,1,0) -3747.483302961461
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 275 / 319 order=(5,0,2), seasonal_order=(0,1,1) -4880.559313175064
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 276 / 319 order=(5,0,2), seasonal_order=(1,0,0) -4958.240637962203
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 277 / 319 order=(5,0,2), seasonal_order=(1,0,1) -4958.408432338386
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 278 / 319 order=(5,0,2), seasonal_order=(1,1,0) -4177.047095220437
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 279 / 319 order=(5,0,2), seasonal_order=(1,1,1) -4867.846498070314
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 280 / 319 order=(5,0,3), seasonal_order=(0,0,0) -4668.439712864806
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 281 / 319 order=(5,0,3), seasonal_order=(0,0,1) -4695.022355346113
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 282 / 319 order=(5,0,3), seasonal_order=(0,1,0) -3787.612959802672
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 283 / 319 order=(5,0,3), seasonal_order=(0,1,1) -4866.824801955241
# 284 / 319 order=(5,0,3), seasonal_order=(1,0,0) -4726.466183972621
# 285 / 319 order=(5,0,3), seasonal_order=(1,0,1) -4676.886856310197
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 286 / 319 order=(5,0,3), seasonal_order=(1,1,0) -4123.387394543008
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 287 / 319 order=(5,0,3), seasonal_order=(1,1,1) -4858.287294766784
# 288 / 319 order=(5,1,0), seasonal_order=(0,0,0) -4963.138480193224
# 289 / 319 order=(5,1,0), seasonal_order=(0,0,1) -4943.978954607198
# 290 / 319 order=(5,1,0), seasonal_order=(0,1,0) -3531.3570817156615
# 291 / 319 order=(5,1,0), seasonal_order=(0,1,1) -4847.509288642306
# 292 / 319 order=(5,1,0), seasonal_order=(1,0,0) -4930.167059036399
# 293 / 319 order=(5,1,0), seasonal_order=(1,0,1) -4931.2389939090435
# 294 / 319 order=(5,1,0), seasonal_order=(1,1,0) -4028.0213246822113
# 295 / 319 order=(5,1,0), seasonal_order=(1,1,1) -4838.210611404395
# 296 / 319 order=(5,1,1), seasonal_order=(0,0,0) -4962.288227523586
# 297 / 319 order=(5,1,1), seasonal_order=(0,0,1) -4940.75354170508
# 298 / 319 order=(5,1,1), seasonal_order=(0,1,0) -3529.34347031014
# 299 / 319 order=(5,1,1), seasonal_order=(0,1,1) -4843.129555040252
# 300 / 319 order=(5,1,1), seasonal_order=(1,0,0) -4930.186687126204
# 301 / 319 order=(5,1,1), seasonal_order=(1,0,1) -4930.365634500868
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 302 / 319 order=(5,1,1), seasonal_order=(1,1,0) -4041.694038050422
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 303 / 319 order=(5,1,1), seasonal_order=(1,1,1) -4837.933740738723
# 304 / 319 order=(5,1,2), seasonal_order=(0,0,0) -4961.036399139251
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 305 / 319 order=(5,1,2), seasonal_order=(0,0,1) -4935.750314472637
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 306 / 319 order=(5,1,2), seasonal_order=(0,1,0) -3534.585525256637
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 307 / 319 order=(5,1,2), seasonal_order=(0,1,1) -4842.093166874668
# 308 / 319 order=(5,1,2), seasonal_order=(1,0,0) -4927.917665390969
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 309 / 319 order=(5,1,2), seasonal_order=(1,0,1) -4927.5139090362645
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 310 / 319 order=(5,1,2), seasonal_order=(1,1,0) -4071.9677961023026
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 311 / 319 order=(5,1,2), seasonal_order=(1,1,1) -4838.653309529964
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 312 / 319 order=(5,1,3), seasonal_order=(0,0,0) -4965.7305408955435
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 313 / 319 order=(5,1,3), seasonal_order=(0,0,1) -4934.976685333425
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 314 / 319 order=(5,1,3), seasonal_order=(0,1,0) -3712.05316731349
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 315 / 319 order=(5,1,3), seasonal_order=(0,1,1) -4869.938919387894
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 316 / 319 order=(5,1,3), seasonal_order=(1,0,0) -4963.4232790206515
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 317 / 319 order=(5,1,3), seasonal_order=(1,0,1) -4966.545714826581
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 318 / 319 order=(5,1,3), seasonal_order=(1,1,0) -4136.438431802395
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 319 / 319 order=(5,1,3), seasonal_order=(1,1,1) -4865.575371760442
# best[aic] parameter ********
#                         model_parameters      aic
# 0  order=(1,0,0), seasonal_order=(0,0,0) -5016.43

# %%
print("best[aic] parameter ********")
print(test_results[test_results.aic == min(test_results.aic)])
print(test_results[test_results.aic == max(test_results.aic)])

# %%
# SRIMAモデル（ちょっとだけパラメータ最適化・総当たりaicベストを適用）
sarimax_optimization = sm.tsa.SARIMAX(diff, 
                        order=(5, 0, 3),
                        seasonal_order=(0, 0, 0, 30),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()

sarimax_optimization_resid = sarimax_optimization.resid # 残差成分

fig = plt.figure(figsize=(8, 8))


# 自己相関(ACF)のグラフ
ax1 = fig.add_subplot(211)
sm.graphics.tsa.plot_acf(sarimax_optimization_resid, lags=40, ax=ax1) #ACF計算とグラフ自動作成

# 偏自己相関(PACF)のグラフ
ax2 = fig.add_subplot(212)
sm.graphics.tsa.plot_pacf(sarimax_optimization_resid, lags=40, ax=ax2) #PACF計算とグラフ自動作成

plt.tight_layout() # グラフ間スキマ調整
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
passengers_train = df_bitcoin[df_bitcoin['日付開始']<'2018-04-01']
passengers_train = passengers_train[['pct_1d','日付開始']]
passengers_train=passengers_train.reset_index()
passengers_train=passengers_train.drop('index',axis=1)
passengers_train=passengers_train.set_index(keys='日付開始')
print(passengers_train.head())
print(passengers_train.tail())
print(passengers_train.isnull().sum())
# Out:
#               pct_1d
# 日付開始
# 2018-03-31 -0.015790
# 2018-03-30  0.040475
# 2018-03-29  0.112616
# 2018-03-28 -0.017827
# 2018-03-27  0.046341
#               pct_1d
# 日付開始
# 2013-05-02  0.095341
# 2013-05-01  0.194363
# 2013-04-30  0.035971
# 2013-04-29 -0.066389
# 2013-04-28  0.006397
# pct_1d    0
# dtype: int64

# %%
passengers_test = df_bitcoin[df_bitcoin['日付開始']>='2018-04-01']
passengers_test = passengers_test[['pct_30d','日付開始']]
passengers_test=passengers_test.reset_index()
passengers_test=passengers_test.drop('index',axis=1)
passengers_test=passengers_test.set_index(keys='日付開始')
passengers_test = passengers_test['pct_30d'].dropna()
print(passengers_test.head())
print(passengers_test.tail())
print(passengers_test.isnull().sum())
# Out:
# 日付開始
# 2018-07-23    0.143143
# 2018-07-22    0.177229
# 2018-07-21    0.131099
# 2018-07-20    0.162681
# 2018-07-19    0.120723
# Name: pct_30d, dtype: float64
# 日付開始
# 2018-04-05   -0.293974
# 2018-04-04   -0.230941
# 2018-04-03   -0.230855
# 2018-04-02   -0.248198
# 2018-04-01   -0.243033
# Name: pct_30d, dtype: float64
# 0

# %%
# SRIMAモデル（テストデータを2年分除いてモデル作成）
sarimax_train = sm.tsa.SARIMAX(passengers_train, 
                        order=(5, 0, 3),
                        seasonal_order=(0, 0, 0, 30),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
sarimax_train_pred = sarimax_train.predict() # テストデータ2年分予測
sarimax_train_pred
# Out:
# 2018-03-31    0.000000
# 2018-03-30   -0.005647
# 2018-03-29    0.020820
# 2018-03-28    0.027127
# 2018-03-27   -0.059924
# 2018-03-26    0.001486
# 2018-03-25   -0.008795
# 2018-03-24   -0.010526
# 2018-03-23   -0.002348
# 2018-03-22    0.003793
# 2018-03-21    0.005956
# 2018-03-20    0.002219
# 2018-03-19   -0.001597
# 2018-03-18   -0.002747
# 2018-03-17    0.001164
# 2018-03-16    0.002921
# 2018-03-15   -0.001320
# 2018-03-14   -0.005504
# 2018-03-13   -0.002770
# 2018-03-12    0.002847
# 2018-03-11    0.001655
# 2018-03-10    0.000783
# 2018-03-09    0.005706
# 2018-03-08    0.002632
# 2018-03-07   -0.001016
# 2018-03-06   -0.005626
# 2018-03-05   -0.000445
# 2018-03-04    0.001508
# 2018-03-03    0.005360
# 2018-03-02    0.006918
#                 ...
# 2013-05-27    0.001481
# 2013-05-26   -0.001102
# 2013-05-25   -0.001627
# 2013-05-24   -0.001839
# 2013-05-23    0.000729
# 2013-05-22    0.002954
# 2013-05-21    0.001665
# 2013-05-20   -0.000906
# 2013-05-19   -0.004366
# 2013-05-18   -0.002567
# 2013-05-17    0.000312
# 2013-05-16    0.001127
# 2013-05-15    0.001319
# 2013-05-14    0.001253
# 2013-05-13    0.000345
# 2013-05-12   -0.004162
# 2013-05-11   -0.004629
# 2013-05-10    0.000270
# 2013-05-09    0.004571
# 2013-05-08    0.001346
# 2013-05-07   -0.000263
# 2013-05-06   -0.000757
# 2013-05-05   -0.002095
# 2013-05-04   -0.001875
# 2013-05-03   -0.002161
# 2013-05-02    0.005139
# 2013-05-01    0.005981
# 2013-04-30   -0.004535
# 2013-04-29   -0.013982
# 2013-04-28   -0.002019
# Freq: -1D, Length: 1799, dtype: float64

# %%
sarimax_train_pred.head()
# Out:
# 2018-03-31    0.000000
# 2018-03-30   -0.005647
# 2018-03-29    0.020820
# 2018-03-28    0.027127
# 2018-03-27   -0.059924
# Freq: -1D, dtype: float64

# %%
plt.figure(figsize=(8, 8))

plt.plot(df_bitcoin['日付開始'],df_bitcoin['pct_30d'],label="original")
plt.plot(sarimax_train_pred, c="b", label="model-pred")
plt.legend(loc='best')

# %% [markdown]
# # 新旧区切り

# %%
passengers_train = df_bitcoin[df_bitcoin['日付開始']<'2018-04-01']
passengers_train = passengers_train[['pct_30d','日付開始']]
passengers_train=passengers_train.reset_index()
passengers_train=passengers_train.drop('index',axis=1)
passengers_train=passengers_train.set_index(keys='日付開始')
print(passengers_train.head())
print(passengers_train.tail())
print(passengers_train.isnull().sum())
# Out:
#              pct_30d
# 日付開始
# 2018-03-31 -0.268789
# 2018-03-30 -0.232705
# 2018-03-29 -0.107414
# 2018-03-28 -0.156480
# 2018-03-27 -0.075256
#              pct_30d
# 日付開始
# 2013-05-02 -0.096569
# 2013-05-01  0.079193
# 2013-04-30  0.088847
# 2013-04-29  0.042171
# 2013-04-28  0.042614
# pct_30d    0
# dtype: int64

# %%
passengers_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1799 entries, 2018-03-31 to 2013-04-28
# Data columns (total 1 columns):
# pct_30d    1799 non-null float64
# dtypes: float64(1)
# memory usage: 28.1 KB

# %%
passengers_test = df_bitcoin[df_bitcoin['日付開始']>='2018-04-01']
passengers_test = passengers_test[['pct_30d','日付開始']]
passengers_test=passengers_test.reset_index()
passengers_test=passengers_test.drop('index',axis=1)
passengers_test=passengers_test.set_index(keys='日付開始')
passengers_test = passengers_test['pct_30d'].dropna()
print(passengers_test.head())
print(passengers_test.tail())
print(passengers_test.isnull().sum())
# Out:
# 日付開始
# 2018-07-23    0.143143
# 2018-07-22    0.177229
# 2018-07-21    0.131099
# 2018-07-20    0.162681
# 2018-07-19    0.120723
# Name: pct_30d, dtype: float64
# 日付開始
# 2018-04-05   -0.293974
# 2018-04-04   -0.230941
# 2018-04-03   -0.230855
# 2018-04-02   -0.248198
# 2018-04-01   -0.243033
# Name: pct_30d, dtype: float64
# 0

# %%
passengers_test.tail()
# Out:
# 日付開始
# 2018-04-05   -0.293974
# 2018-04-04   -0.230941
# 2018-04-03   -0.230855
# 2018-04-02   -0.248198
# 2018-04-01   -0.243033
# Name: pct_30d, dtype: float64

# %%
# モデルの値でプロット
sarimax_pred = sarimax.predict(start=pd.to_datetime('2013-04-28'),end=('2018-03-31')) 
plt.figure(figsize=(8, 4))
plt.plot(sarimax_pred, c="b")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-560-218cd6154846> in <module>()
#       1 # モデルの値でプロット
# ----> 2 sarimax_pred = sarimax.predict(start=pd.to_datetime('2013-04-28'),end=('2018-03-31'))
#       3 plt.figure(figsize=(8, 4))
#       4 plt.plot(sarimax_pred, c="b")
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py in wrapper(self, *args, **kwargs)
#      93             obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#      94         elif how:
# ---> 95             obj = data.wrap_output(func(results, *args, **kwargs), how)
#      96         return obj
#      97
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in predict(self, start, end, dynamic, **kwargs)
#    2367         """
#    2368         # Perform the prediction
# -> 2369         prediction_results = self.get_prediction(start, end, dynamic, **kwargs)
#    2370         return prediction_results.predicted_mean
#    2371
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in get_prediction(self, start, end, dynamic, exog, **kwargs)
#    1880
#    1881         # Handle end (e.g. date)
# -> 1882         _start = self.model._get_predict_start(start)
#    1883         _end, _out_of_sample = self.model._get_predict_end(end)
#    1884
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _get_predict_start(self, start)
#     130             start = str(start)
#     131             if dates is None:
# --> 132                 raise ValueError("Got a string for start and dates is None")
#     133             dtstart = self._str_to_date(start)
#     134             self.data.predict_start = dtstart
#
# ValueError: Got a string for start and dates is None

# %%
sarimax_train = sm.tsa.SARIMAX(passengers_train, 
                        order=(2, 0, 3),
                        seasonal_order=(0, 0, 0, 17),
                        enforce_stationarity = False,
                        enforce_invertibility = False
                        ).fit()

# %%
sarimax_train

# %%
#passengers_train=passengers_train.reset_index()
#passengers_test=passengers_test.reset_index()

# %%
sarimax_train_pred = sarimax_train.predict(start = pd.to_datetime('2018-01-01'),end=pd.to_datetime('2016-01-01')) # テストデータ2年分予測

# %%
sarimax_train_pred.tail()
# Out:
# 2016-01-05    0.108529
# 2016-01-04    0.163842
# 2016-01-03    0.141931
# 2016-01-02    0.157135
# 2016-01-01    0.170152
# Freq: -1D, dtype: float64

# %%
plt.figure(figsize=(8, 4))

plt.plot(df_bitcoin['日付開始'],df_bitcoin['pct_30d'],label="original")
plt.plot(sarimax_train_pred, c="b", label="model-pred",color='red')
plt.legend(loc='best')
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2400: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %% [markdown]
# # ARMA方式

# %%
# 結果表示のための関数
def ts_prediction(d, t, order, prepro='diff'):
    '''
    推測値を計算しMSEとコレログラムを描画する関数
    引数
    d: 元データが入ったデータフレーム
    t: 前処理を施したデータのarray / これを元に推測値を計算
    order : モデルの次数が入ったtuple ex) ARMA(3, 2) → (3, 2)
    ただし、今回はARのみに対応
    '''
    pred_seq = np.arange(50, len(d))
    preds = np.empty_like(pred_seq, dtype=float)

    for i, j in enumerate(pred_seq):
            preds[i] = AR(t[(j - 50):j]).fit(maxlag=order).predict(start=50, end=50)
         
    # 前処理の種類に対応した逆変換をおこなう
    if prepro == 'diff':
        pred_restored = preds + d[49:-1]
    elif prepro == 'pct':
        pred_restored = preds * d[49:-1] + d[49:-1]
    elif prepro == 'logdiff':
        pred_restored = np.exp(preds) * d[49:-1]
    else:
        print('{}は対応していない前処理です.'.format(prepro))
        return None

    # 残差の計算
    resid = d[50:].values - pred_restored.values
    # mseの計算
    mse = np.sum(resid**2) / len(pred_restored)

    print('MSE:', mse)
    print('約{}平均的に予測が外れている.'.format(round(np.sqrt(mse))))

    print('残差のコレログラム')
    sm.graphics.tsa.plot_pacf(resid, lags=10)
    plt.show()
    return None

# %%
# データの前処理
data1_diff = df_bitcoin['価格'].diff()
data1_rate = df_bitcoin['価格'].pct_change()
data1_logdiff = np.log(df_bitcoin['価格'] / df_bitcoin['価格'].shift(1))

# %%
# data1
data = df_bitcoin['価格']
target = data1_diff.dropna().values  # targetのindexは元のdataより１前にずれる.

# コレログラムを描画し次数にあたりをつける。
sm.graphics.tsa.plot_acf(target, lags=10)
sm.graphics.tsa.plot_pacf(target, lags=10)
plt.show()


# それぞれのモデルのAICを計算
aic = pd.Series(index=['MA(6)', "MA(8)", "AR(1)", "AR(4)",
                       "ARMA(1,1)", "ARMA(1,2)", "ARMA(2,1)", "ARMA(2,2)"])
aic['MA(6)'] = ARMA(target, order=(0, 6)).fit().aic
aic['MA(8)'] = ARMA(target, order=(0, 8)).fit().aic
aic['AR(1)'] = ARMA(target, order=(1, 0)).fit().aic
aic['AR(4)'] = ARMA(target, order=(4, 0)).fit().aic
aic['ARMA(1,1)'] = ARMA(target, order=(1, 1)).fit().aic
aic['ARMA(1,2)'] = ARMA(target, order=(1, 2)).fit(trend='nc').aic
aic['ARMA(2,1)'] = ARMA(target, order=(2, 1)).fit().aic
aic['ARMA(2,2)'] = ARMA(target, order=(2, 2)).fit().aic

display(aic.sort_values())  # AICが最小のモデルは？

ts_prediction(data, target, order=4)
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# MA(8)        26688.426047
# MA(6)        26700.251594
# ARMA(1,1)    26736.910469
# ARMA(2,2)    26740.556489
# AR(4)        26746.682053
# ARMA(1,2)    26751.433594
# AR(1)        26752.548541
# ARMA(2,1)    26752.895602
# dtype: float64
# MSE: 62566.53617226937
# 約250.0平均的に予測が外れている.
# 残差のコレログラム

# %%
# data1
data = df_bitcoin['価格']
target = data1_rate.dropna().values  # targetのindexは元のdataより１前にずれる.

# コレログラムを描画し次数にあたりをつける。
sm.graphics.tsa.plot_acf(target, lags=10)
sm.graphics.tsa.plot_pacf(target, lags=10)
plt.show()

    # それぞれのモデルのAICを計算
aic = pd.Series(index=['MA(5)', "AR(1)", "AR(4)",
                       "ARMA(1,1)", "ARMA(1,2)", "ARMA(2,1)", "ARMA(2,2)"])
aic['MA(5)'] = ARMA(target, order=(0, 5)).fit().aic
aic['AR(1)'] = ARMA(target, order=(1, 0)).fit().aic
aic['AR(4)'] = ARMA(target, order=(4, 0)).fit().aic
aic['ARMA(0,0)'] = ARMA(target, order=(0, 0)).fit().aic


display(aic.sort_values())  # AICが最小のモデルは？

ts_prediction(data, target, prepro='pct', order=4)
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# ARMA(0,0)   -6556.656488
# AR(1)       -6554.757700
# MA(5)       -6553.619127
# AR(4)       -6550.984547
# ARMA(1,1)            NaN
# ARMA(1,2)            NaN
# ARMA(2,1)            NaN
# ARMA(2,2)            NaN
# dtype: float64
# MSE: 64670.923930355595
# 約254.0平均的に予測が外れている.
# 残差のコレログラム

# %%
# data1
data = df_bitcoin['価格']
target = data1_logdiff.dropna().values  # targetのindexは元のdataより１前にずれる.

# コレログラムを描画し次数にあたりをつける。
sm.graphics.tsa.plot_acf(target, lags=10)
sm.graphics.tsa.plot_pacf(target, lags=10)
plt.show()

# それぞれのモデルのAICを計算
aic = pd.Series(index=['MA(5)', "AR(1)", "AR(4)",
                       "ARMA(1,1)", "ARMA(1,2)", "ARMA(2,1)", "ARMA(2,2)"])
aic['MA(5)'] = ARMA(target, order=(0, 5)).fit().aic
aic['AR(1)'] = ARMA(target, order=(1, 0)).fit().aic
aic['AR(4)'] = ARMA(target, order=(4, 0)).fit().aic
aic['ARMA(0,0)'] = ARMA(target, order=(0, 0)).fit().aic

display(aic.sort_values())  # AICが最小のモデルは？

ts_prediction(data, target, prepro='logdiff', order=4)
# Out:
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\hiroyuki_ohkawa\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# ARMA(0,0)   -6582.032733
# AR(1)       -6580.066281
# MA(5)       -6579.720904
# AR(4)       -6576.474218
# ARMA(1,1)            NaN
# ARMA(1,2)            NaN
# ARMA(2,1)            NaN
# ARMA(2,2)            NaN
# dtype: float64
# MSE: 64483.28257686195
# 約254.0平均的に予測が外れている.
# 残差のコレログラム

# %%
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

# %%
# 関数化
def AR_pred(index):
   
    # AR(1)を用いて予測
    pred = AR(target[index - 51:index - 1]).fit(maxlag=1).predict(start=50, end=50)#ここで定常化から予測までやってる

    # 実測値（Actual)と比べて予測値(Predict)はどうなっているでしょうか？
    plt.figure(figsize=(5, 5))
    plt.plot(np.arange(1, index), target[:index - 1])
    plt.scatter(np.arange(1, index), target[:index - 1], s=15)
    plt.scatter(index, target[index - 1], c='green', label='Actual', alpha=0.8, s=60)
    plt.scatter(index, pred, c='r', label='Predict', alpha=0.8)
    plt.legend()
    plt.show()

    # 逆変換し、原系列で見てみましょう.
    pred_restored = pred + df_bitcoin.loc[index - 1, '価格']
    plt.figure(figsize=(3, 3))
    plt.scatter(index, pred_restored, c='r', label='Predict')
    plt.plot(np.arange(index), df_bitcoin.loc[:index - 1,'価格'], c='green', linewidth=1, label='Predict')
    plt.scatter(index, df_bitcoin.loc[index, '価格'], s=28, color='green', label='Actual')
    plt.legend()
    ax.xaxis.set_major_formatter(FormatStrFormatter(df_bitcoin['価格']))
    plt.ylabel('austres', fontsize=17)
    plt.show()
    return None

# %%
AR_pred(51)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-97f8cfa9e732> in <module>()
#       1
# ----> 2 AR_pred(51)
#
# <ipython-input-130-9c34a52de4f3> in AR_pred(index)
#      18     plt.figure(figsize=(3, 3))
#      19     plt.scatter(index, pred_restored, c='r', label='Predict')
# ---> 20     plt.plot(np.arange(index), df_bitcoin.loc[:index - 1,'価格'], c='green', linewidth=1, label='Predict')
#      21     plt.scatter(index, df_bitcoin.loc[index, '価格'], s=28, color='green', label='Actual')
#      22     plt.legend()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (51,) and (50,)

# %%
# 2回目の予測
AR_pred(52)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-3c2ab4a2f96c> in <module>()
#       1 # 2回目の予測
# ----> 2 AR_pred(52)
#
# <ipython-input-117-086b269246d7> in AR_pred(index)
#      22     plt.figure(figsize=(3, 3))
#      23     plt.scatter(index, pred_restored, c='r', label='Predict')
# ---> 24     plt.plot(np.arange(index), df_bitcoin.loc[:index - 1,'価格'], c='green', linewidth=1, label='')
#      25     plt.scatter(index, df_bitcoin.loc[index, '価格'], s=28, color='green', label='Actual')
#      26     plt.legend()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (52,) and (51,)

# %%
# SAVE1

# 次のfor文で利用する. pred_seq予測する値のインデックスを格納する. preds予測した値を格納する.
pred_seq = np.arange(100, len(df_bitcoin))
preds = np.empty_like(pred_seq, dtype=float)

for i, j in enumerate(pred_seq):
    preds[i] = AR(target[(j - 100):j]).fit(maxlag=1).predict(start=100, end=100)#ここの１文が重要

fig, axes = plt.subplots(1, 2, figsize=(20, 10))
axes[0].plot(np.arange(1, len(df_bitcoin)), target, label='Actual')
axes[0].plot(pred_seq, preds, c='r', label='Predict')
axes[0].scatter(np.arange(1, len(df_bitcoin)), target, label='', s=15)
axes[0].scatter(pred_seq, preds, c='r', label='', s=15)
axes[0].set_ylabel('diff_austres', fontsize=17)
axes[0].legend()

# 逆変換
pred_restored = preds + pd.TimedeltaIndex(df_bitcoin[100:-1]['日付開始'], unit='D')


axes[1].plot(np.arange(len(df_bitcoin)), df_bitcoin['価格'], c='green', linewidth=1, label='Actual')
axes[1].scatter(np.arange(len(data1)), df_bitcoin['価格'], c='green', s=15, label='')
axes[1].plot(pred_seq, pred_restored, c='r', linewidth=2, label='Predict')
axes[1].legend()
axes[1].set_ylabel('価格', fontsize=17)
axes[1].set_xlim(30, 89)
axes[1].set_ylim(15000, 18000)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# TypeError: object of type 'int' has no len()
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# <ipython-input-157-c29e9a3eea93> in <module>()
#      18
#      19 # 逆変換
# ---> 20 pred_restored = preds + pd.TimedeltaIndex(df_bitcoin[100:-1]['日付開始'], unit='D')
#      21
#      22
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\timedeltas.py in __new__(cls, data, unit, freq, start, end, periods, copy, name, closed, verify_integrity, **kwargs)
#     220
#     221         if unit is not None:
# --> 222             data = to_timedelta(data, unit=unit, box=False)
#     223
#     224         if not isinstance(data, (np.ndarray, Index, ABCSeries)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py in to_timedelta(arg, unit, box, errors)
#      79         from pandas import Series
#      80         values = _convert_listlike(arg._values, unit=unit,
# ---> 81                                    box=False, errors=errors)
#      82         return Series(values, index=arg.index, name=arg.name)
#      83     elif isinstance(arg, ABCIndexClass):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py in _convert_listlike(arg, unit, box, errors, name)
#     171         try:
#     172             value = tslib.array_to_timedelta64(_ensure_object(arg),
# --> 173                                                unit=unit, errors=errors)
#     174             value = value.astype('timedelta64[ns]', copy=False)
#     175         except ValueError:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_timedelta64()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_timedelta64()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.convert_to_timedelta64()
#
# pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.cast_from_unit()
#
# OverflowError: int too big to convert

# %%
# SAVE1

# 次のfor文で利用する. pred_seq予測する値のインデックスを格納する. preds予測した値を格納する.
pred_seq = np.arange(50, len(df_bitcoin))
preds = np.empty_like(pred_seq, dtype=float)

for i, j in enumerate(pred_seq):
    preds[i] = AR(target[(j - 50):j]).fit(maxlag=4).predict(start=50, end=50)#ここの１文が重要

fig, axes = plt.subplots(1, 2, figsize=(20, 10))
axes[0].plot(np.arange(1, len(df_bitcoin)), target, label='Actual')
axes[0].plot(pred_seq, preds, c='r', label='Predict')
axes[0].scatter(np.arange(1, len(df_bitcoin)), target, label='', s=15)
axes[0].scatter(pred_seq, preds, c='r', label='', s=15)
axes[0].set_ylabel('diff_austres', fontsize=17)
axes[0].legend()

# 逆変換
pred_restored = preds + df_bitcoin[49:-1]['価格']

axes[1].plot(np.arange(len(df_bitcoin)), df_bitcoin['価格'], c='green', linewidth=1, label='Actual')
axes[1].scatter(np.arange(len(df_bitcoin)), df_bitcoin['価格'], c='green', s=15, label='')
axes[1].plot(pred_seq, pred_restored, c='r', linewidth=2, label='Predict')
axes[1].legend()
axes[1].set_ylabel('austres', fontsize=17)
axes[1].set_xlim(30, 89)
axes[1].set_ylim(15000, 18000)

plt.show()

# %%
# 最後まで予測してみる

pred_seq = np.arange(61, len(df_bitcoin))
preds = np.empty_like(pred_seq, dtype=float)

for i, j in enumerate(pred_seq):
    preds[i] = AR(target[(j - 61):j - 11]).fit(maxlag=4).predict(start=50, end=59)[-1]

fig, axes = plt.subplots(1, 2, figsize=(20, 10))

axes[0].plot(np.arange(1, len(df_bitcoin)), target, label='Actual')
axes[0].plot(pred_seq, preds, c='r', label='Predict')
axes[0].scatter(np.arange(1, len(df_bitcoin)), target, label='', s=12)
axes[0].scatter(pred_seq, preds, c='r', label='', s=12)
axes[0].legend()
axes[0].set_ylabel('diff_austres', fontsize=17)


# 逆変換
pred_restored = preds + df_bitcoin.loc[61:, '価格']


axes[1].plot(np.arange(len(data1)), df_bitcoin['価格'],
             c='green',  linewidth=1, label='Actual')
axes[1].plot(pred_seq, pred_restored, c='r', linewidth=1, label='Predict')
axes[1].scatter(np.arange(len(data1)), df_bitcoin['価格'], c='green', s=15, label='')
axes[1].scatter(pred_seq, pred_restored, c='r',  s=15, label='')
axes[1].legend()

axes[1].set_ylabel('価格', fontsize=17)
axes[1].set_xlim(50, 89)
axes[1].set_ylim(15750, 18000)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-8f79e123adac> in <module>()
#      18
#      19 # 逆変換
# ---> 20 pred_restored = preds + df_bitcoin.loc[61:, '価格']
#      21
#      22
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name, na_op)
#     737                 lvalues = lvalues.values
#     738
# --> 739         result = wrap_results(safe_na_op(lvalues, rvalues))
#     740         return construct_result(
#     741             left,
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     698         try:
#     699             with np.errstate(all='ignore'):
# --> 700                 return na_op(lvalues, rvalues)
#     701         except Exception:
#     702             if isinstance(rvalues, ABCSeries):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     674
#     675         try:
# --> 676             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     677         except TypeError:
#     678             if isinstance(y, (np.ndarray, ABCSeries, pd.Index)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     202     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#     206
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      62         _store_test_result(False)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#      66
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x, y)
#      76         add=arith_method(operator.add, names('add'), op('+'),
#      77                          default_axis=default_axis),
# ---> 78         radd=arith_method(lambda x, y: y + x, names('radd'), op('+'),
#      79                           default_axis=default_axis),
#      80         sub=arith_method(operator.sub, names('sub'), op('-'),
#
# ValueError: operands could not be broadcast together with shapes (1882,) (1883,)

# %%
# MSEの計算  SAVE1を実行してからこのセルを実行してください

# 予測値と実測値の間に誤差があることを確認するためのグラフ
plt.figure(figsize=(5, 5))
plt.plot(np.arange(len(df_bitcoin)),df_bitcoin['価格'], c='green', linewidth=1, label='Actual')
plt.plot(pred_seq, pred_restored, c='r', linewidth=1, label='Predict')
plt.scatter(np.arange(len(df_bitcoin)), df_bitcoin['価格'], c='green', s=35)
plt.scatter(pred_seq, pred_restored, c='r', s=35)
plt.ylabel('価格', fontsize=17)
plt.xlim(57, 60)
plt.ylim(15900, 16000)
plt.show()


# mseの計算
# mseは実測値と予測値の間にどれだけ誤差があるかの指標.
resid = df_bitcoin.loc[50:, 'austres'] - pred_restored.values  #SAVE1を実行しなおすこと！！！！！
mse = np.sum(resid**2) / len(pred_restored)

print('MSE:', mse)
print('約{}平均的に予測が外れている.'.format(round(np.sqrt(mse))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-63b544fddccc> in <module>()
#       4 plt.figure(figsize=(5, 5))
#       5 plt.plot(np.arange(len(df_bitcoin)),df_bitcoin['価格'], c='green', linewidth=1, label='Actual')
# ----> 6 plt.plot(pred_seq, pred_restored, c='r', linewidth=1, label='Predict')
#       7 plt.scatter(np.arange(len(df_bitcoin)), df_bitcoin['価格'], c='green', s=35)
#       8 plt.scatter(pred_seq, pred_restored, c='r', s=35)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (1882,) and (1893,)

# %%
# 元データの自己相関
print('元データの自己相関')
sm.graphics.tsa.plot_acf(df_bitcoin['価格'], lags=40)
plt.show()
# Out:
# 元データの自己相関

# %%
# 残差の自己相関
print('残差の自己相関')
sm.graphics.tsa.plot_pacf(resid, lags=10)
plt.show()
# Out:
# 残差の自己相関
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-85c7fa81ee34> in <module>()
#       1 # 残差の自己相関
#       2 print('残差の自己相関')
# ----> 3 sm.graphics.tsa.plot_pacf(resid, lags=10)
#       4 plt.show()
#
# NameError: name 'resid' is not defined

# %%
np.asarray(df_bitcoin)
# Out:
# array([[Timestamp('2018-08-22 00:00:00'), 6486.25, 6816.79, ..., nan,
#         nan, nan],
#        [Timestamp('2018-08-21 00:00:00'), 6301.07, 6500.87, ..., nan,
#         nan, nan],
#        [Timestamp('2018-08-20 00:00:00'), 6500.51, 6536.92, ..., nan,
#         nan, nan],
#        ...,
#        [Timestamp('2013-04-30 00:00:00'), 144.0, 146.93, ...,
#         118.94428571430475, 120.40033333332357, 115.81833333333284],
#        [Timestamp('2013-04-29 00:00:00'), 134.44, 147.49, ...,
#         121.5814285714476, 120.58166666665691, 116.36333333333283],
#        [Timestamp('2013-04-28 00:00:00'), 135.3, 135.98, ...,
#         124.78142857144759, 120.76599999999026, 116.88499999999951]],
#       dtype=object)

# %%
df_bitcoin.corr()
# Out:
#                         価格      最高価格      最低価格        終値      時価総額  kouteisa  \
# 価格                1.000000  0.998909  0.998055  0.997537  0.999836  0.818965
# 最高価格              0.998909  1.000000  0.998039  0.999149  0.998594  0.829722
